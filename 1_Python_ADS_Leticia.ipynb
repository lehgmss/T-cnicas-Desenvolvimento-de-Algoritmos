# %% [markdown]
# Nome: Letícia Gomes
#
# Turma: ADS - Quinta - Noturno
#
# Disciplina: Técnicas de Desenvolvimento de Algoritmo
#
# ![download.webp](data:image/webp;base64,...)

# %%
print ("ola, turma!")

# %%
#operadores

"""
Como usar Python como calculadora. Abaixo será necessário informar um valor para a variável a.
"""
print()
a=80
30*5+a-2

# %%
# divisão
# 3//10 é diferente 3/10
"""
//divisão por inteiro
/ divisão
"""
3/10

# %%
'''
operadores textuais
• concatenação: + (juntar, é o & do Flowgorithm, é a (vírgula) no código em python)
• repetição: * (multiplicar)
'''
faculdade="UnB"
nome="Amanda"
print("Eu estudo no ", faculdade, (3*50)) #exemplo de concatenação
print("A estudante de nome ", nome, "estuda no ", faculdade)

# %%
#Lista 1 (11/09)
"""
1. Escreva um programa que apresente na tela a frase: "Meu primeiro programa!!!
"""
print("Meu primeiro programa!!!")

# %%
#2)Escreva um programa que solicite ao usuário um número inteiro e ao final apresente na tela o número informado pelo usuário do programa
numero_inteiro=int(input("Digite um número inteiro: "))
print("O número digitado foi: ", numero_inteiro)

# %%
#3)Escreva um programa que solicite ao usuário um número inteiro e ao final apresente na tela o número informado da seguinte forma: "Foi informado o valor: X
numero_inteiro=int(input("Digite um número inteiro: "))
print("Foi informado o valor: ", numero_inteiro)

# %%
#4)Escreva um programa que solicite ao usuário dois números inteiros e ao final apresente na tela os dois números informados da seguinte forma: "Voce informou os numeros X e Y
numero_inteiro1=int(input("Digite um número inteiro: "))
numero_inteiro2=int(input("Digite um número inteiro: "))
print("Voce informou os numeros", numero_inteiro1, "e", numero_inteiro2)

# %%
#5)Escreva um programa que solicite ao usuário um número real e ao final apresente na tela o número informado formatado com duas casas decimais da seguinte forma: "Voce informou o numero X.YY
numero_real=float(input("Digite um número real: "))
print("Voce informou o numero", round(numero_real,2))

# %%
#6)Escreva um programa que solicite ao usuário a temperatura em graus Celsius e ao final apresente a temperatura correspondente em graus Farenheit. F = Celsius * 1.8 + 32
temperatura_celsius=float(input("Digite a temperatura em graus Celsius:  "))
temperatura_farenheit=temperatura_celsius*1.8+32
print("A temperatura em graus Farenheit é: ", temperatura_farenheit)

# %%
#7)Escreva um programa que solicite ao usuário um número inteiro e um número real e ao final apresente na tela os dois números informados formatando com duas casas decimais somente o número real da seguinte forma: "Voce informou os numeros N e X.YY
numero_inteiro=int(input("Digite um número inteiro: "))
numero_real=float(input("Digite um número real: "))
print("Voce informou os numeros", numero_inteiro, "e", round(numero_real,2))

# %%
#8)Escreva um programa que solicite ao usuário a primeira letra de seu nome e ao final apresente na tela a letra informada pelo usuário da seguinte forma: "Voce digitou w
letra=input("Digite a primeira letra de seu nome: ")
print("Voce digitou", letra)

# %%
#9)Escreva um programa que solicite ao usuário o nome de sua cor preferida e ao final apresente na tela a cor informada pelo usuário da seguinte forma: "Voce gosta da cor AAA
cor_favorita=input("Digite o nome de sua cor favorita: ")
print("Voce gosta da cor", cor_favorita)

# %%
#10) Escreva um programa que solicite ao usuário o nome de uma verdura e uma fruta de sua preferencia e ao final apresente na tela as informações digitadas pelo usuário da seguinte forma: "Voce gosta de AAAAAAA e BBBBBBB
verdura=input("Digite o nome de uma verdura: ")
fruta=input("Digite o nome de uma fruta: ")
print("Voce gosta de", verdura, "e", fruta)

# %%
#11)Elabore um algoritmo que solicite ao usuário um número real e ao final imprima na tela o numero informado e na linha de baixo o dobro deste número da seguinte forma: Numero -> X Dobro deste numero -> Y
numero_real=float(input("Digite um número real: "))
print("Numero ->", numero_real)
print("Dobro deste numero ->", numero_real*2)

# %%
#12)Reescrever o programa anterior apresentando o quadrado e o cubo do número informado
numero_real=floatnumero_real = float(input("Digite um número real: "))
print("Número ->", numero_real)
print("Dobro deste número ->", numero_real * 2)
print("Quadrado deste número ->", numero_real ** 2)
print("Cubo deste número ->", numero_real ** 3)

# %%
#13)Escreva um programa que solicite ao usuário dois números inteiros e ao final apresente na tela a soma dos dois números informados da seguinte forma: "O numeros N e X somados correspondem a Y
numero_inteiro1=int(input("Digite um número inteiro: "))
numero_inteiro2=int(input("Digite um número inteiro: "))
print("O numeros", numero_inteiro1, "e", numero_inteiro2, "somados correspondem a", numero_inteiro1+numero_inteiro2)

# %%
#14)Escreva um programa que solicite ao usuário dois números reais e ao final apresente na tela o produto dos dois números informados da seguinte forma: "O produto dos numeros N e X corresponde a Y
numero_real1=float(input("Digite um número real: "))
numero_real2=float(input("Digite um número real: "))
print("O produto dos numeros", numero_real1, "e", numero_real2, "corresponde a", numero_real1*numero_real2)

# %%
#15)Refazer o programa 14 realizando as quatro operações aritméticas básicas
numero_real1=float(input("Digite um número real:  "))
numero_real2=float(input("Digite um número real:  "))
print("O produto dos numeros ", numero_real1, "e", numero_real2, "corresponde a", numero_real1*numero_real2)
print("O produto dos numeros ", numero_real1, "e", numero_real2, "corresponde a", numero_real1+numero_real2)
print("O produto dos numeros ", numero_real1, "e", numero_real2, "corresponde a", numero_real1-numero_real2)
print("O produto dos numeros ", numero_real1, "e", numero_real2, "corresponde a", numero_real1/numero_real2)

# %% [markdown]
# Lista 2 - Estruturas condicionais (IF, ELIF, ELSE)

# %%
"""
1. Elabore um programa que solicite ao usuário um número real e ao final imprima na tela se o
número informado é maior que 10 (dez)
"""
numero_real = float(input("Informe um número real: "))
if numero_real > 10:
    print("O número informado foi:", numero_real, "- Ele é maior que 10.")

# %%
"""
2. Escreva um programa que solicite ao usuário um número real e ao final imprima na tela se
o número informado é maior ou igual a dez ou menor que 10 (dez)
"""
numero_real1 = float (input("Informe um número real: "))
if numero_real1 >= 10:
  print("O número informado foi:", numero_real1, "- Ele é maior ou igual a 10.")
elif numero_real1 < 10:
  print("O número informado foi:", numero_real1, "- Ele é menor que 10.")

# %%
"""
3. Elabore um algoritmo que solicite ao usuário um número real e ao final imprima na tela se o
número informado é maior que dez, se é menor que dez, ou se é igual a dez
"""
numero_real2=float(input("Informe um número real: "))
if numero_real2 > 10:
  print("O número informado foi:", numero_real2, " Ele é maior que 10.")
elif numero_real2 < 10:
  print("O número informado foi:", numero_real2, " Ele é menor que 10.")

# %%
"""
4. Elabore um algoritmo que solicite ao usuário um número real e ao final imprima na tela se o
número informado é positivo, negativo ou nulo (zero)
"""
numero_real3 = float(input ("Informe um número real: "))
if numero_real3 > 0:
  print("O número informado foi:", numero_real3, "- Ele é positivo.")
elif numero_real3 < 0:
  print("O número informado foi:", numero_real3, "- Ele é negativo.")

# %%
"""
5. Elabore um algoritmo que leia um número inteiro e imprima uma das mensagens: é múltiplo
de 3, ou, não é múltiplo de 3
"""
numero_inteiro1 = int(input("Informe um número inteiro: "))
if numero_inteiro1 % 3 == 0:
  print("O número informado foi:", numero_inteiro1, "- Ele é múltiplo de 3.")
elif numero_inteiro1 % 3 != 0:
  print("O número informado foi:", numero_inteiro1, "- Ele não é múltiplo de 3.")

# %%
"""
6. Refazer o exercício anterior, solicitando antes o múltiplo a ser testado
"""
numero = int(input("Informe um número inteiro: "))
multiplo = int(input("Informe o múltiplo a ser testado: "))
if numero % multiplo == 0:
    print(f"O número {numero} é múltiplo de {multiplo}.")
else:
    print(f"O número {numero} NÃO é múltiplo de {multiplo}.")

# %%
"""
7. Desenvolva um algoritmo que classifique um número inteiro fornecido pelo usuário como
par ou ímpar
"""
numero_inteiro3=int(input("Informe um número inteiro: "))
if numero_inteiro3 % 2 == 0:
  print("O número informado foi:", numero_inteiro3, "- Ele é par.")
elif numero_inteiro3 % 2 != 0:
    print("O número informado foi:", numero_inteiro3, "- Ele é ímpar.")

# %%
"""
8. Elabore um algoritmo que leia um número, e se ele for maior do que 20, imprimir a metade
desse número, caso contrário, imprimir o dobro do número
"""
numero_real4 = float(input("Informe um número real: "))
if numero_real4 > 20:
  print("O número informado foi:", numero_real4, "- Ele é maior que 20. Logo, sua metade é:", numero_real4/2)
elif numero_real4 < 20:
  print("O número informado foi:", numero_real4, "- Ele é menor que 20. Logo, seu dobro é:", numero_real4*2)

# %%
"""
9. Elabore um algoritmo que leia dois números inteiros e realize a adição; caso o resultado
seja maior que 10, imprima o quadrado do resultado, caso contrário, imprima a metade dele
"""
numero_inteiro4 = int(input("Informe um número inteiro: "))
numero_inteiro5 = int(input("Informe um número inteiro: "))
soma = numero_inteiro4 + numero_inteiro5
if soma > 10:
  print("O quadrado do resultado é:", soma**2)
elif soma < 10:
  print("A metade do resultado é:", soma/2)

# %%
"""
10. O sistema de avaliação de determinada disciplina é composto por três provas. A primeira
prova tem peso 2, a segunda tem peso 3 e a terceira tem peso 5. Considerando que a
média para aprovação é 6.0, faça um algoritmo para calcular a média final de um aluno
desta disciplina e dizer se o aluno foi aprovado ou não
"""
prova1 = float(input("Informe a nota da primeira prova: "))
prova2 = float(input("Informe a nota da segunda prova: "))
prova3 = float(input("Informe a nota da terceira prova: "))
media = (prova1*2 + prova2*3 + prova3*5)/10
if media >= 6:
  print("O aluno foi aprovado com média:", media)
elif media < 6:
  print("O aluno foi reprovado com média:", media)

# %%
"""
11. Elabore um algoritmo que leia o nome e o peso de duas pessoas e imprima o nome da
pessoa mais pesada
"""
nome1 = input("Informe o nome da primeira pessoa: ")
peso1 = float(input("Informe o peso da primeira pessoa: "))
nome2 = input("Informe o nome da segunda pessoa: ")
peso2 = float(input("Informe o peso da segunda pessoa: "))
if peso1 > peso2:
  print("A pessoa mais pesada é:", nome1)
elif peso2 > peso1:
  print("A pessoa mais pesada é:", nome2)

# %%
"""
12. Elabore um algoritmo que indique se um número digitado está compreendido entre 20 e
90, ou não
"""
numero = int(input("Informe um número: "))
if numero >= 20 and numero <= 90:
  print("O número está compreendido entre 20 e 90.")
  print("O número é:", numero)
else:
  print("O número NÃO está compreendido entre 20 e 90.")
  print("O número é:", numero)

# %%
"""
13. Elabore um algoritmo que leia dois números e imprima qual é maior, qual é menor, ou se
são iguais
"""
numero1 = int(input("Informe um número: "))
numero2 = int(input("Informe um número: "))
if numero1 > numero2:
  print("O número maior é:", numero1)
  print("O número menor é:", numero2)
  print("Os números são diferentes.")
elif numero2 > numero1:
  print("O número maior é:", numero2)
  print("O número menor é:", numero1)
  print("Os números são diferentes.")

# %%
"""
14. Escreva um programa em linguagem C que solicite ao usuário a média para aprovação
em um curso e em seguida solicite ao usuário o nome, sexo e as 03 notas do aluno e ao
final imprima a frase: "O aluno XXXXX foi aprovado com media YY" considerando o gênero
do(a) aluno(a) e se foi aprovado(a) ou reprovado(a)
"""
media_aprovacao = float(input("Informe a média para aprovação: "))
nome = input("Informe o nome do aluno: ")
sexo = input("Informe o gênero do aluno (feminino/masculino): ").strip().lower()
nota1 = float(input("Informe a primeira nota: "))
nota2 = float(input("Informe a segunda nota: "))
nota3 = float(input("Informe a terceira nota: "))

media = (nota1 + nota2 + nota3) / 3
aprovado = media >= media_aprovacao

if sexo == "feminino":
    artigo = "A aluna"
elif sexo == "masculino":
    artigo = "O aluno"
else:
    artigo = "O(a) aluno(a)"

status = "aprovado(a)" if aprovado else "reprovado(a)"
print(f"{artigo} {nome} foi {status} com média {media:.2f}")
